# %% [markdown]
# ## Presentation of Jupyter Notebook
# <hr>

# %% [markdown]
# <a id="markdown"></a>

# %% [markdown]
# ### Markdown example

# %% [markdown]
# *[Markdown example](#markdown)<br>
# *[LaTex example](#latex)<br>
# *[Communication between cells](#comm1)<br>
# *[Different outputs](#output)<br>
# *[Communication between files](#comm2)<br>
# *[Machine Learning](#ML)<br>

# %% [markdown]
# <h3>Form:</h3>
#
# <form align="left">
#     <input type="search" name="q" placeholder="Rechercher">
#     <input type="submit" value="Lancer !">
# </form>
#
# <h3>Data scientist:</h3>
#
# <table align="left">
#   <tr>
#     <td>Name</td>
#     <td>Jack</td>
#     <td>Toto</td>
#   </tr>
#   <tr>
#     <td>Field</td>
#     <td>Metagenomics</td>
#     <td>Data visualization</td>
#   </tr>
# </table>

# %% [markdown]
# <a id="latex"></a>

# %% [markdown]
# ### LaTex example

# %% [markdown]
# You just need to put your formula between $$

# %% [markdown]
# $$
# \frac{arg 1}{arg 2} \\
# x^2\\
# e^{i\pi}\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{arg}
# $$

# %% [markdown]
# <a id="comm1"></a>

# %% [markdown]
# ### Communication between cells

# %%
def function(x):
    '''Function that return the value'''
    return x
# call function
function("example")
# Out:
# 'example'

# %%
# call function
function("Hello !")
# Out:
# 'Hello !'

# %% [markdown]
# <h3 style="color:red;">Big caution of the running order !</h3>

# %% [markdown]
# <a id="output"></a>

# %% [markdown]
# ### Different output

# %%
print("Hello!")
# Out:
# Hello!

# %%
import pandas as pd

# download flower dataset 
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# import data using DataFrame
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])

print(df)
# Out:
#      sepal length  sepal width  petal length  petal width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns

# extract penguins dataset 
penguins = sns.load_dataset("penguins")
# histogram creation 
sns.histplot(data=penguins, x="flipper_length_mm", bins=30, kde=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# histogram creation 
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# histogram merged  
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step")
sns.histplot(data=penguins, x="flipper_length_mm", bins=30, kde=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# extract flowers dataset 
iris = sns.load_dataset("iris")
species = iris.pop("species")
# clustermap 
sns.clustermap(iris, cmap="plasma")

# %%
import ipywidgets as widgets

def addition(x):
    '''Function that add 10 to the value'''
    return x+10
# bar 
widgets.interact(addition, x=10)
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
# <function __main__.addition(x)>

# %%
def show(x):
    '''Function that return the value'''
    return x
# scrolling menu 
widgets.interact(show, x=['good','bad']);
# Out:
# interactive(children=(Dropdown(description='x', options=('good', 'bad'), value='good'), Output()), _dom_classe…

# %%
# checkbox 
widgets.Checkbox(value=False, description="Check this")
# Out:
# Checkbox(value=False, description='Check this')

# %%
# text area 
widgets.Textarea(value="Enter text here..")
# Out:
# Textarea(value='Enter text here..')

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot(m,c):
    '''Function to create a random plot'''
    # random number 
    x = np.random.rand(10)
    # equation 
    y = m *x + c
    # plot creation 
    plt.plot(x,y)
    plt.show()
# bars + plot 
widgets.interactive(plot, m=(-10,10, 0.5), c=(-5,5,0.5))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='m', max=10.0, min=-10.0, step=0.5), FloatSlider(valu…

# %% [markdown]
# <a id="comm2"></a>

# %% [markdown]
# ### Communication between files

# %%
import os 
import sys

# connect path to use python files inside 
sys.path.append(os.path.abspath("/Users/matt/Desktop"))
# import python file 
import classJupyter

# %%
# create object 
me = classJupyter.DataScientist()
# custom object 
me.changeName("Matthieu")
me.add("Gammaproteobacteria")
me.add("Machine learning")
# presentation 
me.present()
# Out:
# My name is Matthieu and I'm working on Machine learning, Gammaproteobacteria...

# %% [markdown]
# <a id="ML"></a>

# %% [markdown]
# ### Machine learning

# %%
import pandas as pd
# download flower dataset 
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])

print(df)
# Out:
#      sepal length  sepal width  petal length  petal width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler

features = ['sepal length', 'sepal width', 'petal length', 'petal width']
x = df.loc[:, features].values
y = df.loc[:,['target']].values
# standarization 
x = StandardScaler().fit_transform(x)

print(x[:10])
# Out:
# [[-0.90068117  1.03205722 -1.3412724  -1.31297673]
#  [-1.14301691 -0.1249576  -1.3412724  -1.31297673]
#  [-1.38535265  0.33784833 -1.39813811 -1.31297673]
#  [-1.50652052  0.10644536 -1.2844067  -1.31297673]
#  [-1.02184904  1.26346019 -1.3412724  -1.31297673]
#  [-0.53717756  1.95766909 -1.17067529 -1.05003079]
#  [-1.50652052  0.80065426 -1.3412724  -1.18150376]
#  [-1.02184904  0.80065426 -1.2844067  -1.31297673]
#  [-1.74885626 -0.35636057 -1.3412724  -1.31297673]
#  [-1.14301691  0.10644536 -1.2844067  -1.4444497 ]]

# %%
from sklearn.decomposition import PCA

# set number of components
pca = PCA(n_components=2)
# fit/transform data
principalComponents = pca.fit_transform(x)
# recreate DataFrame 
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

print(principalDf)
# Out:
#      principal component 1  principal component 2
# 0                -2.264542               0.505704
# 1                -2.086426              -0.655405
# 2                -2.367950              -0.318477
# 3                -2.304197              -0.575368
# 4                -2.388777               0.674767
# ..                     ...                    ...
# 145               1.870522               0.382822
# 146               1.558492              -0.905314
# 147               1.520845               0.266795
# 148               1.376391               1.016362
# 149               0.959299              -0.022284
#
# [150 rows x 2 columns]

# %%
# merge DataFrames 
finalDf = pd.concat([principalDf, df[['target']]], axis = 1)

print(finalDf)
# Out:
#      principal component 1  principal component 2          target
# 0                -2.264542               0.505704     Iris-setosa
# 1                -2.086426              -0.655405     Iris-setosa
# 2                -2.367950              -0.318477     Iris-setosa
# 3                -2.304197              -0.575368     Iris-setosa
# 4                -2.388777               0.674767     Iris-setosa
# ..                     ...                    ...             ...
# 145               1.870522               0.382822  Iris-virginica
# 146               1.558492              -0.905314  Iris-virginica
# 147               1.520845               0.266795  Iris-virginica
# 148               1.376391               1.016362  Iris-virginica
# 149               0.959299              -0.022284  Iris-virginica
#
# [150 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# creation plot 
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

# add colors based on values 
targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)

# add legend/grid  
ax.legend(targets)
ax.grid()

# explained variance
pca.explained_variance_ratio_
# Out:
# array([0.72770452, 0.23030523])

# %% [markdown]
# ### Learning model creation, deep learning...
